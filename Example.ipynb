# %%
from Scweet.scweet import scrap
from Scweet.user import get_user_information, get_users_following, get_users_followers

# %% [markdown]
# # Scrape tweets of a specific account or words or hashtag

# %%
# scrape top tweets with the words 'covid','covid19' in proximity and without replies.
# the process is slower as the interval is smaller (choose an interval that can divide the period of time betwee, start and max date)
data = scrap(words=['covid','covid19'], start_date="2020-04-01", max_date="2020-04-15", from_account = None,interval=1, 
      headless=True, display_type="Top", save_images=False, 
             resume=False, filter_replies=True, proximity=True)
# Out:
# Scraping on headless mode.
# looking for tweets between 2020-04-01 and 2020-04-02 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-02%20since%3A2020-04-01%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-01T17:00:33.000Z is found.
# Tweet made at: 2020-04-01T19:39:51.000Z is found.
# Tweet made at: 2020-04-01T19:44:02.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# scroll  4
# looking for tweets between 2020-04-02 and 2020-04-03 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-03%20since%3A2020-04-02%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-02T11:24:36.000Z is found.
# Tweet made at: 2020-04-02T18:31:42.000Z is found.
# Tweet made at: 2020-04-02T17:49:18.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-03 and 2020-04-04 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-04%20since%3A2020-04-03%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-03T11:48:11.000Z is found.
# Tweet made at: 2020-04-03T00:16:16.000Z is found.
# Tweet made at: 2020-04-03T10:54:33.000Z is found.
# Tweet made at: 2020-04-02T20:33:53.000Z is found.
# Tweet made at: 2020-04-03T00:35:12.000Z is found.
# scroll  1
# Tweet made at: 2020-04-02T20:33:53.000Z is found.
# scroll  2
# Tweet made at: 2020-04-02T20:33:53.000Z is found.
# scroll  3
# scroll  4
# looking for tweets between 2020-04-04 and 2020-04-05 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-05%20since%3A2020-04-04%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-04T12:11:38.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-05 and 2020-04-06 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-06%20since%3A2020-04-05%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-05T08:34:22.000Z is found.
# Tweet made at: 2020-04-05T11:46:04.000Z is found.
# Tweet made at: 2020-04-05T16:21:56.000Z is found.
# Tweet made at: 2020-04-05T21:21:09.000Z is found.
# Tweet made at: 2020-04-05T20:25:19.000Z is found.
# scroll  1
# Tweet made at: 2020-04-05T22:06:32.000Z is found.
# Tweet made at: 2020-04-05T15:23:39.000Z is found.
# scroll  2
# scroll  3
# scroll  4
# looking for tweets between 2020-04-06 and 2020-04-07 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-07%20since%3A2020-04-06%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-06T10:33:10.000Z is found.
# Tweet made at: 2020-04-06T13:38:29.000Z is found.
# Tweet made at: 2020-04-06T03:43:13.000Z is found.
# Tweet made at: 2020-04-06T18:37:04.000Z is found.
# Tweet made at: 2020-04-06T23:20:49.000Z is found.
# Tweet made at: 2020-04-06T21:20:03.000Z is found.
# scroll  1
# Tweet made at: 2020-04-06T09:13:59.000Z is found.
# Tweet made at: 2020-04-06T21:00:33.000Z is found.
# Tweet made at: 2020-04-06T21:03:25.000Z is found.
# scroll  2
# scroll  3
# scroll  4
# looking for tweets between 2020-04-07 and 2020-04-08 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-08%20since%3A2020-04-07%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-07T14:18:13.000Z is found.
# Tweet made at: 2020-04-07T09:25:46.000Z is found.
# Tweet made at: 2020-04-07T13:31:30.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-08 and 2020-04-09 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-09%20since%3A2020-04-08%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-08T21:19:10.000Z is found.
# Tweet made at: 2020-04-08T21:38:09.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-09 and 2020-04-10 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-10%20since%3A2020-04-09%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-09T11:07:46.000Z is found.
# scroll  1
# Tweet made at: 2020-04-09T11:07:46.000Z is found.
# scroll  2
# scroll  3
# looking for tweets between 2020-04-10 and 2020-04-11 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-11%20since%3A2020-04-10%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-10T00:05:05.000Z is found.
# Tweet made at: 2020-04-10T15:18:51.000Z is found.
# Tweet made at: 2020-04-10T15:47:13.000Z is found.
# Tweet made at: 2020-04-10T23:15:21.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# scroll  4
# looking for tweets between 2020-04-11 and 2020-04-12 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-12%20since%3A2020-04-11%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-11T19:04:07.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-12 and 2020-04-13 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-13%20since%3A2020-04-12%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-12T17:39:17.000Z is found.
# Tweet made at: 2020-04-11T22:49:20.000Z is found.
# Tweet made at: 2020-04-12T10:55:30.000Z is found.
# scroll  1
# Tweet made at: 2020-04-12T10:55:30.000Z is found.
# Tweet made at: 2020-04-11T22:48:54.000Z is found.
# Tweet made at: 2020-04-12T11:00:05.000Z is found.
# scroll  2
# Tweet made at: 2020-04-12T10:55:30.000Z is found.
# Tweet made at: 2020-04-12T11:00:05.000Z is found.
# scroll  3
# scroll  4
# looking for tweets between 2020-04-13 and 2020-04-14 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-14%20since%3A2020-04-13%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-13T16:58:57.000Z is found.
# Tweet made at: 2020-04-13T09:11:45.000Z is found.
# Tweet made at: 2020-04-13T19:25:56.000Z is found.
# Tweet made at: 2020-04-13T09:15:23.000Z is found.
# Tweet made at: 2020-04-13T21:34:58.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-14 and 2020-04-15 ...
#  path : https://twitter.com/search?q=(covid%20OR%20covid19)%20until%3A2020-04-15%20since%3A2020-04-14%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-14T13:05:35.000Z is found.
# Tweet made at: 2020-04-14T23:05:35.000Z is found.
# Tweet made at: 2020-04-14T23:01:59.000Z is found.
# scroll  1
# Tweet made at: 2020-04-14T14:28:58.000Z is found.
# Tweet made at: 2020-04-14T16:28:46.000Z is found.
# Tweet made at: 2020-04-14T22:27:25.000Z is found.
# Tweet made at: 2020-04-14T22:36:06.000Z is found.
# scroll  2
# scroll  3
# scroll  4

# %%
# scrape top tweets of with the hashtag #covid19, in proximity and without replies.
# the process is slower as the interval is smaller (choose an interval that can divide the period of time betwee, start and max date)
data = scrap(hashtag="covid19", start_date="2020-04-01", max_date="2020-04-15", from_account = None,interval=1, 
      headless=True, display_type="Top", save_images=False, 
             resume=False, filter_replies=True, proximity=True)
# Out:
# Scraping on headless mode.
# looking for tweets between 2020-04-01 and 2020-04-02 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-02%20since%3A2020-04-01%20%20-filter%3Areplie&src=typed_query&lf=on
# scroll  1
# Tweet made at: 2020-04-01T19:44:02.000Z is found.
# Tweet made at: 2020-04-01T19:39:51.000Z is found.
# scroll  2
# scroll  3
# looking for tweets between 2020-04-02 and 2020-04-03 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-03%20since%3A2020-04-02%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-02T18:31:42.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-03 and 2020-04-04 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-04%20since%3A2020-04-03%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-03T00:16:16.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-04 and 2020-04-05 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-05%20since%3A2020-04-04%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-04T12:11:38.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-05 and 2020-04-06 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-06%20since%3A2020-04-05%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-05T20:25:19.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-06 and 2020-04-07 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-07%20since%3A2020-04-06%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-06T21:20:03.000Z is found.
# Tweet made at: 2020-04-06T21:00:33.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-07 and 2020-04-08 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-08%20since%3A2020-04-07%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-07T14:18:13.000Z is found.
# Tweet made at: 2020-04-07T09:25:46.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-08 and 2020-04-09 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-09%20since%3A2020-04-08%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-08T21:19:10.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-09 and 2020-04-10 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-10%20since%3A2020-04-09%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-09T11:07:46.000Z is found.
# scroll  1
# Tweet made at: 2020-04-09T11:07:46.000Z is found.
# scroll  2
# scroll  3
# looking for tweets between 2020-04-10 and 2020-04-11 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-11%20since%3A2020-04-10%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-10T15:18:51.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2020-04-11 and 2020-04-12 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-12%20since%3A2020-04-11%20%20-filter%3Areplie&src=typed_query&lf=on
# scroll  1
# scroll  2
# looking for tweets between 2020-04-12 and 2020-04-13 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-13%20since%3A2020-04-12%20%20-filter%3Areplie&src=typed_query&lf=on
# scroll  1
# scroll  2
# looking for tweets between 2020-04-13 and 2020-04-14 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-14%20since%3A2020-04-13%20%20-filter%3Areplie&src=typed_query&lf=on
# scroll  1
# scroll  2
# looking for tweets between 2020-04-14 and 2020-04-15 ...
#  path : https://twitter.com/search?q=(%23covid19)%20until%3A2020-04-15%20since%3A2020-04-14%20%20-filter%3Areplie&src=typed_query&lf=on
# Tweet made at: 2020-04-14T16:28:46.000Z is found.
# scroll  1
# scroll  2
# scroll  3

# %%
data.head()
# Out:
#           UserScreenName          UserName                 Timestamp  \
# 0       imane benzarouel  @ImaneBenzarouel  2020-04-01T19:44:02.000Z
# 1             Ghita Tazi          @Ghitazi  2020-04-01T19:39:51.000Z
# 2            Saoud Ayoub       @SaoudAyoub  2020-04-02T18:31:42.000Z
# 3  MasaidBin |\n| مسعدبن         @UN_YEMEN  2020-04-03T00:16:16.000Z
# 4          Leila Dehaibi            @LDHB_  2020-04-04T12:11:38.000Z
#
#                                                 Text  \
# 0  BCEAO, intéressantes mesures prises pour encou...
# 1  COVID-19 \nLe nombre des nouveaux cas est en b...
# 2                               #COVID19 #callcenter
# 3  Because of #COVID19, the US economy is collaps...
# 4  #Coronavirusmaroc #بقا_فدارك_باش_تحمي_بلادك #C...
#
#                                        Embedded_text Emojis Comments Likes  \
# 0  Quote Tweet\nJacqueline Niffone\n@Niffone_J_D\...                     1
# 1                                                                  1
# 2
# 3
# 4
#
#   Retweets                                         Image link  \
# 0        1  [https://pbs.twimg.com/profile_images/13466921...
# 1        5                                                 []
# 2        1  [https://pbs.twimg.com/media/EUnnIXQXYAID7Hi?f...
# 3                                                          []
# 4        1  [https://pbs.twimg.com/media/EUwjXd8WoAAokkF?f...
#
#                                            Tweet URL
# 0  https://twitter.com/ImaneBenzarouel/status/124...
# 1  https://twitter.com/Ghitazi/status/12454357309...
# 2  https://twitter.com/SaoudAyoub/status/12457809...
# 3  https://twitter.com/UN_YEMEN/status/1245867680...
# 4  https://twitter.com/LDHB_/status/1246410095845...

# %% [markdown]
# # Get the main information of a given list of users

# %%
# These users belongs to my following. 
users = ['nagouzil', '@yassineaitjeddi', 'TahaAlamIdrissi', 
         '@Nabila_Gl', 'geceeekusuu', '@pabu232', '@av_ahmet', '@x_born_to_die_x']

# %%
# this function return a list that contains : 
# ["nb of following","nb of followers", "join date", "birthdate", "location", "website", "description"]
users_info = get_user_information(users, headless=True)
# Out:
# Scraping on headless mode.
# --------------- nagouzil information : ---------------
# Following :  81
# Followers :  27
# Location :
# Join date :  Joined September 2012
# Birth date :
# Description :  Make a difference
# Website :
# --------------- @yassineaitjeddi information : ---------------
# Following :  120
# Followers :  5
# Location :
# Join date :  Joined October 2016
# Birth date :
# Description :
# Website :
# --------------- TahaAlamIdrissi information : ---------------
# Following :  382
# Followers :  157
# Location :  France
# Join date :  Joined August 2012
# Birth date :
# Description :  #SoftwareEngineeringStudentAtTSE
# #DEVOPS_ENTHUSIAST
# #FULL_STACK_WEB_DEV
# Website :
# --------------- @Nabila_Gl information : ---------------
# Following :  373
# Followers :  437
# Location :  Quelque part
# Join date :  Joined October 2016
# Birth date :  Born October 23
# Description :  « La seule personne de confiance est celle qui craint الله »
#  {Omar Ibn al-khattab}
# Website :
# --------------- geceeekusuu information : ---------------
# Following :  305
# Followers :  240
# Location :  İzmir, Türkiye
# Join date :  Joined April 2012
# Birth date :  Born October 23, 1997
# Description :  Ben olmak çok zor. Bi de unutmayın ki hala genç ve çıtırız
# Hacettepe Üni-DişHekFak
# Website :  https://t.co/zIQJyCBmxX?amp=1
# --------------- @pabu232 information : ---------------
# Following :  4,909
# Followers :  4,884
# Location :  ROYAL
# Join date :  Joined December 2011
# Birth date :
# Description :
# Website :
# --------------- @av_ahmet information : ---------------
# Following :  605
# Followers :  450
# Location :  AVUKAT&ADANA
# Join date :  Joined July 2011
# Birth date :
# Description :  Avukatlar tarih boyu köle kullanmadılar ama hiçbir zaman efendileri de olmadı![Molierac]
# Website :
# --------------- @x_born_to_die_x information : ---------------
# Following :  697
# Followers :  1,501
# Location :  Justin'in yanında
# Join date :  Joined July 2010
# Birth date :
# Description :  I'm  #belieber ,#lovatic .
#   @jusdemkes
#  yedek hesabım :)
# Website :  http://t.co/Ruil1rP8oW?amp=1

# %%
import pandas as pd

users_df = pd.DataFrame(users_info, index = ["nb of following","nb of followers", "join date", 
                                             "birthdate", "location", "website", "description"]).T
users_df
# Out:
#                  nb of following nb of followers              join date  \
# nagouzil                      81              27  Joined September 2012
# @yassineaitjeddi             120               5    Joined October 2016
# TahaAlamIdrissi              382             157     Joined August 2012
# @Nabila_Gl                   373             437    Joined October 2016
# geceeekusuu                  305             240      Joined April 2012
# @pabu232                   4,909           4,884   Joined December 2011
# @av_ahmet                    605             450       Joined July 2011
# @x_born_to_die_x             697           1,501       Joined July 2010
#
#                               birthdate                       location  \
# nagouzil
# @yassineaitjeddi
# TahaAlamIdrissi                                                 France
# @Nabila_Gl              Born October 23  Quelque part
# geceeekusuu       Born October 23, 1997                 İzmir, Türkiye
# @pabu232                                                        ROYAL
# @av_ahmet                                                 AVUKAT&ADANA
# @x_born_to_die_x                                    Justin'in yanında
#
#                                         website  \
# nagouzil
# @yassineaitjeddi
# TahaAlamIdrissi
# @Nabila_Gl
# geceeekusuu       https://t.co/zIQJyCBmxX?amp=1
# @pabu232
# @av_ahmet
# @x_born_to_die_x   http://t.co/Ruil1rP8oW?amp=1
#
#                                                         description
# nagouzil                                          Make a difference
# @yassineaitjeddi
# TahaAlamIdrissi   #SoftwareEngineeringStudentAtTSE\n#DEVOPS_ENTH...
# @Nabila_Gl        « La seule personne de confiance est celle qui...
# geceeekusuu       Ben olmak çok zor. Bi de unutmayın ki hala gen...
# @pabu232
# @av_ahmet         Avukatlar tarih boyu köle kullanmadılar ama hi...
# @x_born_to_die_x  I'm  #belieber ,#lovatic . \n  @jusdemkes\n ye...

# %% [markdown]
# # Get followers and following of a given list of users

# %% [markdown]
# Enter your username and password in .env file. I recommande you dont use your main account.
# Increase wait argument to avoid banning your account and maximise the crawling process if the internet is slow. I used 1 and it's safe.

# %%
following = get_users_following(users=users, verbose=0, headless = True, wait=1)
# Out:
# Scraping on headless mode.
# Crawling @nagouzil following
# Found 9 following
# Found 38 following
# Found 60 following
# Found 80 following
# Found 80 following
# Crawling @@yassineaitjeddi following
# Found 10 following
# Found 40 following
# Found 60 following
# Found 79 following
# Found 99 following
# Found 120 following
# Found 120 following
# Crawling @TahaAlamIdrissi following
# Found 8 following
# Found 37 following
# Found 56 following
# Found 77 following
# Found 98 following
# Found 119 following
# Found 139 following
# Found 159 following
# Found 180 following
# Found 200 following
# Found 219 following
# Found 240 following
# Found 258 following
# Found 279 following
# Found 299 following
# Found 318 following
# Found 338 following
# Found 359 following
# Found 378 following
# Found 381 following
# Found 381 following
# Crawling @lolitapoupat following
# Found 10 following
# Found 39 following
# Found 39 following
# Crawling @@Jade_happiness following
# Found 9 following
# Found 38 following
# Found 58 following
# Found 78 following
# Found 99 following
# Found 120 following
# Found 139 following
# Found 160 following
# Found 180 following
# Found 182 following
# Found 182 following
# Crawling @@Nabila_Gl following
# Found 9 following
# Found 39 following
# Found 60 following
# Found 80 following
# Found 100 following
# Found 119 following
# Found 140 following
# Found 160 following
# Found 180 following
# Found 200 following
# Found 220 following
# Found 240 following
# Found 260 following
# Found 280 following
# Found 298 following
# Found 318 following
# Found 338 following
# Found 357 following
# Found 368 following
# Found 368 following
# Crawling @geceeekusuu following
# Found 9 following
# Found 38 following
# Found 59 following
# Found 78 following
# Found 99 following
# Found 120 following
# Found 139 following
# Found 159 following
# Found 179 following
# Found 200 following
# Found 219 following
# Found 240 following
# Found 259 following
# Found 280 following
# Found 296 following
# Found 296 following

# %%
print(following['nagouzil'])
# Out:
# ['@tweetsauce', '@jockowillink', '@brfootball', '@433', '@Ibra_official', '@HSHQ', '@Snowden', '@johnkrasinski', '@fireship_dev', '@zinebmouchrik', '@Dannmace', '@Kurz_Gesagt', '@reactjs', '@dribbble', '@UpLabs', '@sketch', '@materialdesign', '@GoogleDesign', '@ayoubagouzil', '@garyvee', '@368', '@brielarson', '@Tesla', '@MehdiElIdriss23', '@Spotify', '@DavidDobrik', '@ddlovato', '@Dave2D', '@verge', '@StephenCurry30', '@KingJames', '@olivia_holt', '@saradietschy', '@petermckinnon', '@colesprouse', '@jakerawr', '@Casey', '@MandyPandyLeigh', '@Phil_Coutinho', '@KevinHart4real', '@BillGates', '@elonmusk', '@oneplus', '@dbrand', '@MKBHD', '@UnboxTherapy', '@TheRock', '@JDMorgan', '@AADaddario', '@jimmyfallon', '@ConanOBrien', '@alexandrabreck1', '@RealHughJackman', '@MelissaBenoist', '@HARDWELL', '@TahaAlamIdrissi', '@Eminem', '@SnoopDogg', '@GiGiHadid', '@Ucefmab', '@SalmaRach', '@ultra', '@MartinGarrix', '@YouTube', '@BadoAbdo', '@iWillSmith', '@ivanrakitic', '@Adele', '@SergiRoberto10', '@taylorswift13', '@LuisSuarez9', '@selenagomez', '@KendallJenner', '@jtimberlake', '@CHANEL', '@justinbieber', '@davidguetta', '@TeamMessi', '@neymarjr', '@BarackObama']

# %%
followers = get_users_followers(users=users, verbose=0, headless = True, wait=1)
# Out:
# Scraping on headless mode.
# Crawling @NAgouzil followers
# Found 9 followers
# Found 27 followers
# Found 27 followers
# Crawling @Yassineaitjeddi followers
# Found 5 followers
# Found 5 followers
# Crawling @TahaAlamIdrissi followers
# Found 9 followers
# Found 40 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 119 followers
# Found 140 followers
# Found 157 followers
# Found 157 followers
# Crawling @LolitaPoupat followers
# Found 10 followers
# Found 40 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 120 followers
# Found 134 followers
# Found 134 followers
# Crawling @Jade_happiness followers
# Found 0 followers
# Found 37 followers
# Found 58 followers
# Found 78 followers
# Found 98 followers
# Found 117 followers
# Found 136 followers
# Found 158 followers
# Found 177 followers
# Found 198 followers
# Found 217 followers
# Found 237 followers
# Found 245 followers
# Found 245 followers
# Crawling @nabila_gl followers
# Found 10 followers
# Found 38 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 119 followers
# Found 140 followers
# Found 160 followers
# Found 180 followers
# Found 200 followers
# Found 220 followers
# Found 240 followers
# Found 260 followers
# Found 280 followers
# Found 300 followers
# Found 320 followers
# Found 340 followers
# Found 360 followers
# Found 380 followers
# Found 400 followers
# Found 419 followers
# Found 433 followers
# Found 433 followers

# %%
print(followers['LolitaPoupat'])
# Out:
# ['@BaolBase', '@PrtJessie', '@amzil_naoufal', '@AlexisAymardd', '@Missalgangstar', '@yvane7777', '@LauraIs18', '@royes_lucas', '@GaetanGettgett', '@MehdyNedjar', '@TahiaYounes', '@Nassim95783893', '@BvSportetsante', '@zazazoz74115203', '@KevinJacquet6', '@edouardcrdt', '@Bekkamo_nono', '@DamienCharb', '@RHautiere', '@BaptisteRcr', '@sirina_rebbati', '@influenceuses', '@HadfiYamina', '@AlexPortoss', '@melanie_gdn_', '@BeratKoparan', '@Hasni_vola', '@lhdnn3', '@Hutchiwa1', '@BoukharouaI', '@zz_adil', '@AdrienTheOne', '@Axel_18100', '@Sneek59600743', '@GuilheiraAmelia', '@jaouenTzn', '@mizrahi_10', '@Charles03273937', '@KazmaKazmitch01', '@_beneston', '@Luckies_Smoke', '@meilleurtweet4', '@tiagoantunes205', '@bouyguestelecom', '@Atlatix', '@LeBoyJow', '@God_of_Couscous', '@Gokuku01755', '@Petition_RER_B', '@kmeljbr', '@AdrienPutseys', '@spy_vic', '@SLorenzo_FR', '@Petits_seins', '@diamondStyleez', '@alves_damien', '@thepunisher641', '@parisportif2017', '@aliciaportoss', '@livantsi', '@AlicePe41094652', '@camus_charlotte', '@mnSTEVEN28', '@juunssss', '@mydomydo3', '@st_cha18', '@emmathoreau_18', '@ElabbsiM', '@LaMichaa', '@FelipeLucie', '@theoj07', '@dylan_cls', '@antoinetekass', '@djjo7', '@Myirji', '@ely2i', '@emaxstl', '@TheHow2Guru', '@bruno80170', '@sujandas979', '@Gamzedefnemarda', '@SoulatAmandine1', '@TBelindaa', '@CedricDiMaria', '@YouMrook', '@KellyPmmt', '@abdelhaff', '@JeremThevenin', '@Max_Sola', '@Gambirasio1', '@ArnoJacket', '@SwagShopOff', '@Mrfreeze8z', '@yebda953', '@moodindp', '@LaurelennaLoise', '@TheotimB', '@thiago19912015', '@Mel_anie18', '@uasarf', '@sbrams13', '@CorentinPereira', '@LeryKevin', '@Tomssmontana', '@YanissRebbati', '@CamilleDarlingP', '@T_atianaR', '@BVHippo', '@JulietteJln', '@LauraChudy', '@PaulineTorterat', '@starlordMK', '@Ianiscatinevel', '@AdilNasri', '@AlexCouloumy', '@SophiiaCie', '@Pauline_DSA', '@ga_bZs', '@TiffanyDaMota', '@PintoJenn', '@clara_besse18', '@Ce_Joy18', '@sampson_marvin', '@LauuraForest', '@PauulinePetit', '@RComedien', '@MehdiBoudina', '@LesliieK', '@thediable2', '@DjeH', '@MarinePoupat', '@jimboux', '@AlexiDasilva', '@OphelieHaddadi']
