# %%
from scweet import scrap
from user import get_user_information, get_users_following, get_users_followers

# %% [markdown]
# # Scrape tweets of a specific account "from_account"

# %%
# scrape tweets of @elonmusk that contain images 'display_type = image' and save them in image directory.
# looks like elon only share memes on Twitter
data = scrap(start_date="2020-01-01", max_date="2020-01-20", from_account = "elonmusk",interval=1, 
      headless=True, display_type="image", hashtag=None, save_images=True)
# Out:
# Scraping on headless mode.
# looking for tweets between 2020-01-01 and 2020-01-02 00:00:00 ...
# Tweet made at: 2020-01-01T06:33:47.000Z is found.
# scroll 0
# scroll 1
# scroll 2
# looking for tweets between 2020-01-02 00:00:00 and 2020-01-03 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-03 00:00:00 and 2020-01-04 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-04 00:00:00 and 2020-01-05 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-05 00:00:00 and 2020-01-06 00:00:00 ...
# Tweet made at: 2020-01-05T00:35:42.000Z is found.
# scroll 0
# scroll 1
# looking for tweets between 2020-01-06 00:00:00 and 2020-01-07 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-07 00:00:00 and 2020-01-08 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-08 00:00:00 and 2020-01-09 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-09 00:00:00 and 2020-01-10 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-10 00:00:00 and 2020-01-11 00:00:00 ...
# Tweet made at: 2020-01-10T07:19:46.000Z is found.
# scroll 0
# scroll 1
# looking for tweets between 2020-01-11 00:00:00 and 2020-01-12 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-12 00:00:00 and 2020-01-13 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-13 00:00:00 and 2020-01-14 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-14 00:00:00 and 2020-01-15 00:00:00 ...
# scroll 0
# Tweet made at: 2020-01-14T17:59:16.000Z is found.
# scroll 1
# scroll 2
# looking for tweets between 2020-01-15 00:00:00 and 2020-01-16 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-16 00:00:00 and 2020-01-17 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-17 00:00:00 and 2020-01-18 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-18 00:00:00 and 2020-01-19 00:00:00 ...
# scroll 0
# scroll 1
# looking for tweets between 2020-01-19 00:00:00 and 2020-01-20 00:00:00 ...
# scroll 0
# scroll 1
# Saving images ...

# %%
data
# Out:
#   UserScreenName   UserName                 Timestamp  \
# 0      Elon Musk  @elonmusk  2020-01-01T06:33:47.000Z
# 1      Elon Musk  @elonmusk  2020-01-05T00:35:42.000Z
# 2      Elon Musk  @elonmusk  2020-01-10T07:19:46.000Z
# 3      Elon Musk  @elonmusk  2020-01-14T17:59:16.000Z
#
#                                                 Text Emojis Comments  Likes  \
# 0                      No one suspected his disguise             697   4.8K
# 1                                         Wikigenius            1.9K  29.9K
# 2                                              Phony            1.1K  27.8K
# 3  T-shirt is bulletproof & makes u buff!\nhttps:...            1.8K   3.4K
#
#   Retweets                                         Image link  \
# 0    73.3K  [https://pbs.twimg.com/media/ENLQkiKXYAIAh-a?f...
# 1     293K  [https://pbs.twimg.com/media/ENelARzU0AA6Wxi?f...
# 2   210.8K  [https://pbs.twimg.com/media/EN5xb56U0AAJatv?f...
# 3    46.8K  [https://pbs.twimg.com/media/EOQqKhnUYAAmHVU?f...
#
#                                            Tweet URL
# 0  https://twitter.com/elonmusk/status/1212260614...
# 1  https://twitter.com/elonmusk/status/1213620051...
# 2  https://twitter.com/elonmusk/status/1215533676...
# 3  https://twitter.com/elonmusk/status/1217144162...

# %% [markdown]
# # Get the main information of a given list of users

# %%
# These users belongs to my following. 
users = ['nagouzil', '@yassineaitjeddi', 'TahaAlamIdrissi', 
         '@Nabila_Gl', 'geceeekusuu', '@pabu232', '@av_ahmet', '@x_born_to_die_x']

# %%
# this function return a list that contains : 
# ["nb of following","nb of followers", "join date", "birthdate", "location", "website", "description"]
users_info = get_user_information(users, headless=True)
# Out:
# Scraping on headless mode.
# --------------- nagouzil information : ---------------
# Following :  80
# Followers :  27
# Location :
# Join date :  Joined September 2012
# Birth date :
# Description :  Make a difference
# Website :
# --------------- @yassineaitjeddi information : ---------------
# Following :  120
# Followers :  5
# Location :
# Join date :  Joined October 2016
# Birth date :
# Description :
# Website :
# --------------- TahaAlamIdrissi information : ---------------
# Following :  381
# Followers :  157
# Location :  France
# Join date :  Joined August 2012
# Birth date :
# Description :  #SoftwareEngineeringStudentAtTSE
# #DEVOPS_ENTHUSIAST
# #FULL_STACK_WEB_DEV
# Website :
# --------------- @Nabila_Gl information : ---------------
# Following :  368
# Followers :  431
# Location :  Quelque part
# Join date :  Joined October 2016
# Birth date :  Born October 23
# Description :  « La seule personne de confiance est celle qui craint الله »
#  {Omar Ibn al-khattab}
# Website :
# --------------- geceeekusuu information : ---------------
# Following :  297
# Followers :  231
# Location :  İzmir, Türkiye
# Join date :  Joined April 2012
# Birth date :  Born October 23, 1997
# Description :  Ben olmak çok zor. Bi de unutmayın ki hala genç ve çıtırız
# Hacettepe Üni-DişHekFak
# Website :  https://t.co/zIQJyCBmxX?amp=1
# --------------- @pabu232 information : ---------------
# Following :  4,928
# Followers :  4,904
# Location :  ROYAL
# Join date :  Joined December 2011
# Birth date :
# Description :
# Website :
# --------------- @av_ahmet information : ---------------
# Following :  603
# Followers :  452
# Location :  AVUKAT&ADANA
# Join date :  Joined July 2011
# Birth date :
# Description :  Avukatlar tarih boyu köle kullanmadılar ama hiçbir zaman efendileri de olmadı![Molierac]
# Website :
# --------------- @x_born_to_die_x information : ---------------
# Following :  701
# Followers :  1,501
# Location :  Justin'in yanında
# Join date :  Joined July 2010
# Birth date :
# Description :  I'm  #belieber ,#lovatic .
#   @jusdemkes
#  yedek hesabım :)
# Website :  http://t.co/Ruil1rP8oW?amp=1

# %%
import pandas as pd

users_df = pd.DataFrame(users_info, index = ["nb of following","nb of followers", "join date", 
                                             "birthdate", "location", "website", "description"]).T
users_df
# Out:
#                  nb of following nb of followers              join date  \
# nagouzil                      80              27  Joined September 2012
# @yassineaitjeddi             120               5    Joined October 2016
# TahaAlamIdrissi              381             157     Joined August 2012
# @Nabila_Gl                   368             431    Joined October 2016
# geceeekusuu                  297             231      Joined April 2012
# @pabu232                   4,928           4,904   Joined December 2011
# @av_ahmet                    603             452       Joined July 2011
# @x_born_to_die_x             701           1,501       Joined July 2010
#
#                               birthdate                       location  \
# nagouzil
# @yassineaitjeddi
# TahaAlamIdrissi                                                 France
# @Nabila_Gl              Born October 23  Quelque part
# geceeekusuu       Born October 23, 1997                 İzmir, Türkiye
# @pabu232                                                        ROYAL
# @av_ahmet                                                 AVUKAT&ADANA
# @x_born_to_die_x                                    Justin'in yanında
#
#                                         website  \
# nagouzil
# @yassineaitjeddi
# TahaAlamIdrissi
# @Nabila_Gl
# geceeekusuu       https://t.co/zIQJyCBmxX?amp=1
# @pabu232
# @av_ahmet
# @x_born_to_die_x   http://t.co/Ruil1rP8oW?amp=1
#
#                                                         description
# nagouzil                                          Make a difference
# @yassineaitjeddi
# TahaAlamIdrissi   #SoftwareEngineeringStudentAtTSE\n#DEVOPS_ENTH...
# @Nabila_Gl        « La seule personne de confiance est celle qui...
# geceeekusuu       Ben olmak çok zor. Bi de unutmayın ki hala gen...
# @pabu232
# @av_ahmet         Avukatlar tarih boyu köle kullanmadılar ama hi...
# @x_born_to_die_x  I'm  #belieber ,#lovatic . \n  @jusdemkes\n ye...

# %% [markdown]
# # Get followers and following of a given list of users

# %% [markdown]
# Enter your username and password in .env file. I recommande you dont use your main account.
# Increase wait argument to avoid banning your account and maximise the crawling process if the internet is slow. I used 1 and it's safe.

# %%
following = get_users_following(users=users, verbose=0, headless = True, wait=1)
# Out:
# Scraping on headless mode.
# Crawling @nagouzil following
# Found 9 following
# Found 38 following
# Found 60 following
# Found 80 following
# Found 80 following
# Crawling @@yassineaitjeddi following
# Found 10 following
# Found 40 following
# Found 60 following
# Found 79 following
# Found 99 following
# Found 120 following
# Found 120 following
# Crawling @TahaAlamIdrissi following
# Found 8 following
# Found 37 following
# Found 56 following
# Found 77 following
# Found 98 following
# Found 119 following
# Found 139 following
# Found 159 following
# Found 180 following
# Found 200 following
# Found 219 following
# Found 240 following
# Found 258 following
# Found 279 following
# Found 299 following
# Found 318 following
# Found 338 following
# Found 359 following
# Found 378 following
# Found 381 following
# Found 381 following
# Crawling @lolitapoupat following
# Found 10 following
# Found 39 following
# Found 39 following
# Crawling @@Jade_happiness following
# Found 9 following
# Found 38 following
# Found 58 following
# Found 78 following
# Found 99 following
# Found 120 following
# Found 139 following
# Found 160 following
# Found 180 following
# Found 182 following
# Found 182 following
# Crawling @@Nabila_Gl following
# Found 9 following
# Found 39 following
# Found 60 following
# Found 80 following
# Found 100 following
# Found 119 following
# Found 140 following
# Found 160 following
# Found 180 following
# Found 200 following
# Found 220 following
# Found 240 following
# Found 260 following
# Found 280 following
# Found 298 following
# Found 318 following
# Found 338 following
# Found 357 following
# Found 368 following
# Found 368 following
# Crawling @geceeekusuu following
# Found 9 following
# Found 38 following
# Found 59 following
# Found 78 following
# Found 99 following
# Found 120 following
# Found 139 following
# Found 159 following
# Found 179 following
# Found 200 following
# Found 219 following
# Found 240 following
# Found 259 following
# Found 280 following
# Found 296 following
# Found 296 following

# %%
print(following['nagouzil'])
# Out:
# ['@tweetsauce', '@jockowillink', '@brfootball', '@433', '@Ibra_official', '@HSHQ', '@Snowden', '@johnkrasinski', '@fireship_dev', '@zinebmouchrik', '@Dannmace', '@Kurz_Gesagt', '@reactjs', '@dribbble', '@UpLabs', '@sketch', '@materialdesign', '@GoogleDesign', '@ayoubagouzil', '@garyvee', '@368', '@brielarson', '@Tesla', '@MehdiElIdriss23', '@Spotify', '@DavidDobrik', '@ddlovato', '@Dave2D', '@verge', '@StephenCurry30', '@KingJames', '@olivia_holt', '@saradietschy', '@petermckinnon', '@colesprouse', '@jakerawr', '@Casey', '@MandyPandyLeigh', '@Phil_Coutinho', '@KevinHart4real', '@BillGates', '@elonmusk', '@oneplus', '@dbrand', '@MKBHD', '@UnboxTherapy', '@TheRock', '@JDMorgan', '@AADaddario', '@jimmyfallon', '@ConanOBrien', '@alexandrabreck1', '@RealHughJackman', '@MelissaBenoist', '@HARDWELL', '@TahaAlamIdrissi', '@Eminem', '@SnoopDogg', '@GiGiHadid', '@Ucefmab', '@SalmaRach', '@ultra', '@MartinGarrix', '@YouTube', '@BadoAbdo', '@iWillSmith', '@ivanrakitic', '@Adele', '@SergiRoberto10', '@taylorswift13', '@LuisSuarez9', '@selenagomez', '@KendallJenner', '@jtimberlake', '@CHANEL', '@justinbieber', '@davidguetta', '@TeamMessi', '@neymarjr', '@BarackObama']

# %%
followers = get_users_followers(users=users, verbose=0, headless = True, wait=1)
# Out:
# Scraping on headless mode.
# Crawling @NAgouzil followers
# Found 9 followers
# Found 27 followers
# Found 27 followers
# Crawling @Yassineaitjeddi followers
# Found 5 followers
# Found 5 followers
# Crawling @TahaAlamIdrissi followers
# Found 9 followers
# Found 40 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 119 followers
# Found 140 followers
# Found 157 followers
# Found 157 followers
# Crawling @LolitaPoupat followers
# Found 10 followers
# Found 40 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 120 followers
# Found 134 followers
# Found 134 followers
# Crawling @Jade_happiness followers
# Found 0 followers
# Found 37 followers
# Found 58 followers
# Found 78 followers
# Found 98 followers
# Found 117 followers
# Found 136 followers
# Found 158 followers
# Found 177 followers
# Found 198 followers
# Found 217 followers
# Found 237 followers
# Found 245 followers
# Found 245 followers
# Crawling @nabila_gl followers
# Found 10 followers
# Found 38 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 119 followers
# Found 140 followers
# Found 160 followers
# Found 180 followers
# Found 200 followers
# Found 220 followers
# Found 240 followers
# Found 260 followers
# Found 280 followers
# Found 300 followers
# Found 320 followers
# Found 340 followers
# Found 360 followers
# Found 380 followers
# Found 400 followers
# Found 419 followers
# Found 433 followers
# Found 433 followers

# %%
print(followers['LolitaPoupat'])
# Out:
# ['@BaolBase', '@PrtJessie', '@amzil_naoufal', '@AlexisAymardd', '@Missalgangstar', '@yvane7777', '@LauraIs18', '@royes_lucas', '@GaetanGettgett', '@MehdyNedjar', '@TahiaYounes', '@Nassim95783893', '@BvSportetsante', '@zazazoz74115203', '@KevinJacquet6', '@edouardcrdt', '@Bekkamo_nono', '@DamienCharb', '@RHautiere', '@BaptisteRcr', '@sirina_rebbati', '@influenceuses', '@HadfiYamina', '@AlexPortoss', '@melanie_gdn_', '@BeratKoparan', '@Hasni_vola', '@lhdnn3', '@Hutchiwa1', '@BoukharouaI', '@zz_adil', '@AdrienTheOne', '@Axel_18100', '@Sneek59600743', '@GuilheiraAmelia', '@jaouenTzn', '@mizrahi_10', '@Charles03273937', '@KazmaKazmitch01', '@_beneston', '@Luckies_Smoke', '@meilleurtweet4', '@tiagoantunes205', '@bouyguestelecom', '@Atlatix', '@LeBoyJow', '@God_of_Couscous', '@Gokuku01755', '@Petition_RER_B', '@kmeljbr', '@AdrienPutseys', '@spy_vic', '@SLorenzo_FR', '@Petits_seins', '@diamondStyleez', '@alves_damien', '@thepunisher641', '@parisportif2017', '@aliciaportoss', '@livantsi', '@AlicePe41094652', '@camus_charlotte', '@mnSTEVEN28', '@juunssss', '@mydomydo3', '@st_cha18', '@emmathoreau_18', '@ElabbsiM', '@LaMichaa', '@FelipeLucie', '@theoj07', '@dylan_cls', '@antoinetekass', '@djjo7', '@Myirji', '@ely2i', '@emaxstl', '@TheHow2Guru', '@bruno80170', '@sujandas979', '@Gamzedefnemarda', '@SoulatAmandine1', '@TBelindaa', '@CedricDiMaria', '@YouMrook', '@KellyPmmt', '@abdelhaff', '@JeremThevenin', '@Max_Sola', '@Gambirasio1', '@ArnoJacket', '@SwagShopOff', '@Mrfreeze8z', '@yebda953', '@moodindp', '@LaurelennaLoise', '@TheotimB', '@thiago19912015', '@Mel_anie18', '@uasarf', '@sbrams13', '@CorentinPereira', '@LeryKevin', '@Tomssmontana', '@YanissRebbati', '@CamilleDarlingP', '@T_atianaR', '@BVHippo', '@JulietteJln', '@LauraChudy', '@PaulineTorterat', '@starlordMK', '@Ianiscatinevel', '@AdilNasri', '@AlexCouloumy', '@SophiiaCie', '@Pauline_DSA', '@ga_bZs', '@TiffanyDaMota', '@PintoJenn', '@clara_besse18', '@Ce_Joy18', '@sampson_marvin', '@LauuraForest', '@PauulinePetit', '@RComedien', '@MehdiBoudina', '@LesliieK', '@thediable2', '@DjeH', '@MarinePoupat', '@jimboux', '@AlexiDasilva', '@OphelieHaddadi']
