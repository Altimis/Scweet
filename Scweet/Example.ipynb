# %%
from scweet import scrap
from user import get_user_information, get_users_following, get_users_followers

# %% [markdown]
# # Scrape tweets of a specific account "from_account"

# %%
data = scrap(start_date="2020-01-01", max_date="2020-01-06", from_account = "elonmusk",interval=1, 
      headless=True, display_type="image", hashtag=None, save_images=True)
# Out:
# Scraping on headless mode.
# looking for tweets between 2020-01-01 and 2020-01-02 00:00:00 ...
# Tweet made at: 2020-01-01T06:33:47.000Z is found.
# Tweet made at: 2020-01-01T05:32:58.000Z is found.
# Tweet made at: 2020-01-01T06:50:06.000Z is found.
# scroll 0
# scroll 1
# scroll 2
# looking for tweets between 2020-01-02 00:00:00 and 2020-01-03 00:00:00 ...
# scroll 0
# scroll 1
# scroll 2
# looking for tweets between 2020-01-03 00:00:00 and 2020-01-04 00:00:00 ...
# scroll 0
# scroll 1
# scroll 2
# looking for tweets between 2020-01-04 00:00:00 and 2020-01-05 00:00:00 ...
# Tweet made at: 2020-01-03T19:21:22.000Z is found.
# Tweet made at: 2020-01-04T03:25:03.000Z is found.
# Tweet made at: 2020-01-04T03:21:17.000Z is found.
# Tweet made at: 2020-01-04T03:33:58.000Z is found.
# Tweet made at: 2020-01-04T03:35:20.000Z is found.
# scroll 0
# scroll 1
# scroll 2
# looking for tweets between 2020-01-05 00:00:00 and 2020-01-06 00:00:00 ...
# Tweet made at: 2020-01-05T13:32:27.000Z is found.
# Tweet made at: 2020-01-05T17:51:01.000Z is found.
# Tweet made at: 2020-01-05T00:35:42.000Z is found.
# Tweet made at: 2020-01-05T17:23:17.000Z is found.
# Tweet made at: 2020-01-05T18:08:31.000Z is found.
# scroll 0
# scroll 1
# scroll 2
# Saving images ...

# %%
data
# Out:
#    UserScreenName     UserName                 Timestamp  \
# 0       Elon Musk    @elonmusk  2020-01-01T06:33:47.000Z
# 1       Elon Musk    @elonmusk  2020-01-01T05:32:58.000Z
# 2       Elon Musk    @elonmusk  2020-01-01T06:50:06.000Z
# 3        Slashdot    @slashdot  2020-01-03T19:21:22.000Z
# 4       Elon Musk    @elonmusk  2020-01-04T03:25:03.000Z
# 5       RS Tanner  @hot_rod_co  2020-01-04T03:21:17.000Z
# 6       Elon Musk    @elonmusk  2020-01-04T03:33:58.000Z
# 7       Elon Musk    @elonmusk  2020-01-04T03:35:20.000Z
# 8            Pomp  @APompliano  2020-01-05T13:32:27.000Z
# 9       Elon Musk    @elonmusk  2020-01-05T17:51:01.000Z
# 10      Elon Musk    @elonmusk  2020-01-05T00:35:42.000Z
# 11      Elon Musk    @elonmusk  2020-01-05T17:23:17.000Z
# 12      Elon Musk    @elonmusk  2020-01-05T18:08:31.000Z
#
#                                                  Text     Emojis Comments  \
# 0                       No one suspected his disguise                 697
# 1                                         Carlos Gone                  3K
# 2   Congratulations Tesla & SpaceX on great 2019! ...  ♥ 🚀 🛰 🚘 ☀       2K
# 3   Is Fry's Electronics in Trouble?Is Fry's Elect...                  24
# 4   Wow, I built my first server room with parts f...                 139
# 5   Tesla has now added 112,000 salespeople ... ac...          🚘       48
# 6   People talk about the products they *love*, th...                 290
# 7       Replying to \n@annerajb\n and \n@slashdotZip2                  54
# 8   Don’t look now, but \n@elonmusk\n and \n@Tesla...          🌪      100
# 9                                 Fair piece by Stoll                  62
# 10                                         Wikigenius                1.9K
# 11                      Replying to \n@Model3OwnersOk                 180
# 12       Replying to \n@7400N\n and \n@Model3OwnersOk                 104
#
#     Likes Retweets                                         Image link  \
# 0    4.8K    73.4K  [https://pbs.twimg.com/media/ENLQkiKXYAIAh-a?f...
# 1     19K   131.9K                                                 []
# 2    7.8K   158.2K                                                 []
# 3      26      295  [https://pbs.twimg.com/card_img/13495068961773...
# 4     115     2.3K                                                 []
# 5     174     3.1K                                                 []
# 6     364     6.6K                                                 []
# 7      51     1.3K                                                 []
# 8     977     7.8K  [https://pbs.twimg.com/card_img/13483357068847...
# 9      99     2.9K                                                 []
# 10  29.9K   293.3K  [https://pbs.twimg.com/media/ENelARzU0AA6Wxi?f...
# 11    200       5K                                                 []
# 12    100     3.1K                                                 []
#
#                                             Tweet URL
# 0   https://twitter.com/elonmusk/status/1212260614...
# 1   https://twitter.com/elonmusk/status/1212245306...
# 2   https://twitter.com/elonmusk/status/1212264717...
# 3   https://twitter.com/slashdot/status/1213178555...
# 4   https://twitter.com/elonmusk/status/1213300278...
# 5   https://twitter.com/hot_rod_co/status/12132993...
# 6   https://twitter.com/elonmusk/status/1213302526...
# 7   https://twitter.com/elonmusk/status/1213302866...
# 8   https://twitter.com/APompliano/status/12138155...
# 9   https://twitter.com/elonmusk/status/1213880594...
# 10  https://twitter.com/elonmusk/status/1213620051...
# 11  https://twitter.com/elonmusk/status/1213873615...
# 12  https://twitter.com/elonmusk/status/1213884998...

# %% [markdown]
# # Get the main information of a given list of users

# %%
# These users belongs to my following. 
users = ['nagouzil', '@yassineaitjeddi', 'TahaAlamIdrissi', 'lolitapoupat', '@Jade_happiness', '@Nabila_Gl', 'geceeekusuu']

# %%
#this function return a list that contains : 
#["nb of following","nb of followers", "join date", "birthdate", "location", "website", "description"]
users_info = get_user_information(users, headless=True)
# Out:
# Scraping on headless mode.

# %%
import pandas as pd

users_df = pd.DataFrame(users_info, index = ["nb of following","nb of followers", "join date", 
                                             "birthdate", "location", "website", "description"]).T
users_df
# Out:
#                  nb of following nb of followers              join date  \
# nagouzil                      80              27  Joined September 2012
# @yassineaitjeddi             120               5    Joined October 2016
# TahaAlamIdrissi              381             157     Joined August 2012
# lolitapoupat                  39             134      Joined March 2015
# @Jade_happiness              183             246    Joined October 2011
# @Nabila_Gl                   369             435    Joined October 2016
# geceeekusuu                  296             232      Joined April 2012
#
#                               birthdate                       location  \
# nagouzil
# @yassineaitjeddi
# TahaAlamIdrissi                                                 France
# lolitapoupat
# @Jade_happiness                                  Ile-de-France, France
# @Nabila_Gl              Born October 23  Quelque part
# geceeekusuu       Born October 23, 1997                 İzmir, Türkiye
#
#                                         website  \
# nagouzil
# @yassineaitjeddi
# TahaAlamIdrissi
# lolitapoupat
# @Jade_happiness
# @Nabila_Gl
# geceeekusuu       https://t.co/zIQJyCBmxX?amp=1
#
#                                                         description
# nagouzil                                          Make a difference
# @yassineaitjeddi
# TahaAlamIdrissi   #SoftwareEngineeringStudentAtTSE\n#DEVOPS_ENTH...
# lolitapoupat
# @Jade_happiness   #BelieveTourParis #PurposeTourMontreal #Purpos...
# @Nabila_Gl        « La seule personne de confiance est celle qui...
# geceeekusuu       Ben olmak çok zor. Bi de unutmayın ki hala gen...

# %% [markdown]
# # Get followers and following of a given list of users

# %% [markdown]
# Enter your username and password in .env file. I recommande you dont use your main account.
# Increase wait argument to avoid banning your account and maximise the crawling process if the internet is slow. I used 1 and it's safe.

# %%
following = get_users_following(users=users, verbose=0, headless = True, wait=1)
# Out:
# Scraping on headless mode.
# Crawling @NAgouzil following
# Found 9 following
# Found 38 following
# Found 60 following
# Found 79 following
# Found 81 following
# Found 81 following
# Crawling @Yassineaitjeddi following
# Found 10 following
# Found 40 following
# Found 60 following
# Found 79 following
# Found 99 following
# Found 120 following
# Found 120 following
# Crawling @TahaAlamIdrissi following
# Found 8 following
# Found 37 following
# Found 56 following
# Found 77 following
# Found 98 following
# Found 119 following
# Found 139 following
# Found 159 following
# Found 180 following
# Found 200 following
# Found 219 following
# Found 240 following
# Found 258 following
# Found 279 following
# Found 299 following
# Found 318 following
# Found 339 following
# Found 359 following
# Found 378 following
# Found 380 following
# Found 380 following
# Crawling @LolitaPoupat following
# Found 10 following
# Found 39 following
# Found 39 following
# Crawling @Jade_happiness following
# Found 9 following
# Found 38 following
# Found 58 following
# Found 79 following
# Found 99 following
# Found 120 following
# Found 139 following
# Found 160 following
# Found 180 following
# Found 182 following
# Found 182 following
# Crawling @nabila_gl following
# Found 9 following
# Found 38 following
# Found 60 following
# Found 80 following
# Found 100 following
# Found 119 following
# Found 140 following
# Found 160 following
# Found 180 following
# Found 200 following
# Found 220 following
# Found 239 following
# Found 260 following
# Found 260 following
# Found 294 following
# Found 315 following
# Found 334 following
# Found 353 following
# Found 363 following
# Found 363 following

# %%
print(following['NAgouzil'])
# Out:
# ['@tweetsauce', '@jockowillink', '@brfootball', '@433', '@Ibra_official', '@HSHQ', '@Snowden', '@johnkrasinski', '@fireship_dev', '@zinebmouchrik', '@Dannmace', '@Kurz_Gesagt', '@reactjs', '@dribbble', '@UpLabs', '@sketch', '@materialdesign', '@GoogleDesign', '@ayoubagouzil', '@garyvee', '@368', '@brielarson', '@Tesla', '@MehdiElIdriss23', '@Spotify', '@DavidDobrik', '@ddlovato', '@Dave2D', '@verge', '@StephenCurry30', '@KingJames', '@olivia_holt', '@saradietschy', '@petermckinnon', '@colesprouse', '@jakerawr', '@Casey', '@hkasulka', '@MandyPandyLeigh', '@Phil_Coutinho', '@KevinHart4real', '@BillGates', '@elonmusk', '@oneplus', '@dbrand', '@MKBHD', '@UnboxTherapy', '@TheRock', '@JDMorgan', '@AADaddario', '@jimmyfallon', '@ConanOBrien', '@alexandrabreck1', '@RealHughJackman', '@MelissaBenoist', '@HARDWELL', '@TahaAlamIdrissi', '@Eminem', '@SnoopDogg', '@GiGiHadid', '@Ucefmab', '@SalmaRach', '@ultra', '@MartinGarrix', '@YouTube', '@BadoAbdo', '@iWillSmith', '@ivanrakitic', '@Adele', '@SergiRoberto10', '@taylorswift13', '@LuisSuarez9', '@selenagomez', '@KendallJenner', '@jtimberlake', '@CHANEL', '@justinbieber', '@davidguetta', '@TeamMessi', '@neymarjr', '@BarackObama']

# %%
followers = get_users_followers(users=users, verbose=0, headless = True, wait=1)
# Out:
# Scraping on headless mode.
# Crawling @NAgouzil followers
# Found 9 followers
# Found 27 followers
# Found 27 followers
# Crawling @Yassineaitjeddi followers
# Found 5 followers
# Found 5 followers
# Crawling @TahaAlamIdrissi followers
# Found 9 followers
# Found 40 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 119 followers
# Found 140 followers
# Found 157 followers
# Found 157 followers
# Crawling @LolitaPoupat followers
# Found 10 followers
# Found 40 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 120 followers
# Found 134 followers
# Found 134 followers
# Crawling @Jade_happiness followers
# Found 0 followers
# Found 37 followers
# Found 58 followers
# Found 78 followers
# Found 98 followers
# Found 117 followers
# Found 136 followers
# Found 158 followers
# Found 177 followers
# Found 198 followers
# Found 217 followers
# Found 237 followers
# Found 245 followers
# Found 245 followers
# Crawling @nabila_gl followers
# Found 10 followers
# Found 38 followers
# Found 60 followers
# Found 80 followers
# Found 100 followers
# Found 119 followers
# Found 140 followers
# Found 160 followers
# Found 180 followers
# Found 200 followers
# Found 220 followers
# Found 240 followers
# Found 260 followers
# Found 280 followers
# Found 300 followers
# Found 320 followers
# Found 340 followers
# Found 360 followers
# Found 380 followers
# Found 400 followers
# Found 419 followers
# Found 433 followers
# Found 433 followers

# %%
print(followers['LolitaPoupat'])
# Out:
# ['@BaolBase', '@PrtJessie', '@amzil_naoufal', '@AlexisAymardd', '@Missalgangstar', '@yvane7777', '@LauraIs18', '@royes_lucas', '@GaetanGettgett', '@MehdyNedjar', '@TahiaYounes', '@Nassim95783893', '@BvSportetsante', '@zazazoz74115203', '@KevinJacquet6', '@edouardcrdt', '@Bekkamo_nono', '@DamienCharb', '@RHautiere', '@BaptisteRcr', '@sirina_rebbati', '@influenceuses', '@HadfiYamina', '@AlexPortoss', '@melanie_gdn_', '@BeratKoparan', '@Hasni_vola', '@lhdnn3', '@Hutchiwa1', '@BoukharouaI', '@zz_adil', '@AdrienTheOne', '@Axel_18100', '@Sneek59600743', '@GuilheiraAmelia', '@jaouenTzn', '@mizrahi_10', '@Charles03273937', '@KazmaKazmitch01', '@_beneston', '@Luckies_Smoke', '@meilleurtweet4', '@tiagoantunes205', '@bouyguestelecom', '@Atlatix', '@LeBoyJow', '@God_of_Couscous', '@Gokuku01755', '@Petition_RER_B', '@kmeljbr', '@AdrienPutseys', '@spy_vic', '@SLorenzo_FR', '@Petits_seins', '@diamondStyleez', '@alves_damien', '@thepunisher641', '@parisportif2017', '@aliciaportoss', '@livantsi', '@AlicePe41094652', '@camus_charlotte', '@mnSTEVEN28', '@juunssss', '@mydomydo3', '@st_cha18', '@emmathoreau_18', '@ElabbsiM', '@LaMichaa', '@FelipeLucie', '@theoj07', '@dylan_cls', '@antoinetekass', '@djjo7', '@Myirji', '@ely2i', '@emaxstl', '@TheHow2Guru', '@bruno80170', '@sujandas979', '@Gamzedefnemarda', '@SoulatAmandine1', '@TBelindaa', '@CedricDiMaria', '@YouMrook', '@KellyPmmt', '@abdelhaff', '@JeremThevenin', '@Max_Sola', '@Gambirasio1', '@ArnoJacket', '@SwagShopOff', '@Mrfreeze8z', '@yebda953', '@moodindp', '@LaurelennaLoise', '@TheotimB', '@thiago19912015', '@Mel_anie18', '@uasarf', '@sbrams13', '@CorentinPereira', '@LeryKevin', '@Tomssmontana', '@YanissRebbati', '@CamilleDarlingP', '@T_atianaR', '@BVHippo', '@JulietteJln', '@LauraChudy', '@PaulineTorterat', '@starlordMK', '@Ianiscatinevel', '@AdilNasri', '@AlexCouloumy', '@SophiiaCie', '@Pauline_DSA', '@ga_bZs', '@TiffanyDaMota', '@PintoJenn', '@clara_besse18', '@Ce_Joy18', '@sampson_marvin', '@LauuraForest', '@PauulinePetit', '@RComedien', '@MehdiBoudina', '@LesliieK', '@thediable2', '@DjeH', '@MarinePoupat', '@jimboux', '@AlexiDasilva', '@OphelieHaddadi']
